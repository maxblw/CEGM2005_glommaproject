# %%
# #tair = data 
# T_melt = 0 
# #k is some constant  
# ice_melt_rate = k * (t_air - T_melt) # in mm/hour or kg/m2/s
# ice_melt = ice_melt_rate * duration
# Pice = ice_melt
# Pr = daily_rainfall - infiltration_loss - evaporation_loss 
# Qs = (Pr * duration ) + ice_melt * catchment_area
